# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup as bs
from pprint import pprint

# %%
URL = 'https://moscow.hh.ru/search/vacancy'
search_query = 'консультант'

# Классы HH.ru

data_div = 'vacancy-serp__results' # container
vacancy_div = 'vacancy-serp-item' # vacancy

name_class = 'resume-search-item__name' # vacancy_name
company_class = 'vacancy-serp-item__meta-info' # company_name link in <a>

# name_class = 'resume-search-item__name' # vacancy_name
name_class = 'bloko-link HH-LinkModifier' # vacancy_name


data = []

# %%
def parse_to_data(search_query):    
    params = {
        'text': search_query, \
        'search_field': 'name', \
        'items_on_page': '100', \
        'page': ''
    }

    headers = {
        'User-Agent': \
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'
    }

    link = 'https://hh.ru/search/vacancy'

    html = requests.get(link, params=params, headers=headers)

    # page count check

    if html.ok:
        parsed_html = bs(html.text,'html.parser')

        page_block = parsed_html.find('div', {'data-qa': 'pager-block'}) # page switching block
        if not page_block:
            last_page = '1'        
        else:
            last_page = int(page_block.find_all('a', {'class': 'HH-Pager-Control'})[-2].getText())  

        for page in range(0, last_page):    # last_page
            params['page'] = page
            html = requests.get(link, params=params, headers=headers)

            if html.ok:
                parsed_html = bs(html.text,'html.parser')

                vacancy_items = parsed_html.find('div', {'data-qa': data_div}) \
                                            .find_all('div', {'class': vacancy_div})

                for item in vacancy_items:
                    data.append(_parser_vacancy_div(item))
    #                 data.append(item)

# %%
def _parser_vacancy_div(item):

    vacancy_data = {}
    
#     pprint(item)
    
    # vacancy_name
    vacancy_name = item.find('a', {'data-qa':"vacancy-serp__vacancy-title"}).text
    
    vacancy_data['vacancy_name'] = vacancy_name
    
    # vacancy_add_time
    vacancy_add_time = item.find('span', {'class':"vacancy-serp-item__publication-date"})
    if vacancy_add_time:
        vacancy_add_time = " ".join(vacancy_add_time.text.split())
    else:
        vacancy_add_time = None
    
    vacancy_data['vacancy_add_time'] = vacancy_add_time
    
    # company_name
    company_name = item.find('a', {'data-qa':"vacancy-serp__vacancy-employer"}).text
    
    vacancy_data['company_name'] = company_name
    
    # city
    city = item.find('span', {'data-qa':"vacancy-serp__vacancy-address"}).text
    city = city.split(',')[0]
    
    vacancy_data['city'] = city
    
    vacancy_data['salary_min'], vacancy_data['salary_max'], vacancy_data['currency'] = get_salarys_and_currency(item)
   
    
    return vacancy_data

# %%
def get_salarys_and_currency(item):
    salary = item.find('span', {'data-qa':"vacancy-serp__vacancy-compensation"})
    if salary:
        salary = salary.text.replace('\xa0', '').replace('-', ' ').split()
  

        if salary[0] == 'до':
            salary_min = None
            salary_max = int(salary[1])
        elif salary[0] == 'от':
            salary_min = int(salary[1])
            salary_max = None
        else:
            salary_min = int(salary[0])
            salary_max = int(salary[1])
            
#             compound currency check
            
        try:
            int(salary[-2])
            currency = salary[-1]
        except:
            currency = f'{salary[-2]} {alary[-1]}'


    else:
        salary_min = None
        salary_max = None
        currency = None
    return [salary_min, salary_max, currency,]

# %% [markdown]
# Странно, но на HH нет самого очевидного варианта: указать зарплату точно. 100000 руб., например.
# Либо "от", либо "до", либо вилка.

# %%
parse_to_data(search_query)

# %%
df = pd.DataFrame(data)

# %%
from collections import Counter
c = Counter(df['vacancy_name']).most_common(3)
requests_list = []
for el in c:
    requests_list.append(el[0])
    
# pprint(requests_list)

# %%
data = []

for el in requests_list:
    parse_to_data(el)

# %%
# df = pd.DataFrame(data)

# %% [markdown]
# Удалю повторы. В том числе и объявления, поданные несколько раз в разные даты, т.к. речь суть об одном предложении вакансии.

# %%
# df.drop_duplicates(subset=['vacancy_name', 'company_name'], keep=False)

# %% [markdown]
# # HW3
# ## mongo DB

# %%
from pymongo import MongoClient, errors

import zlib

# %%
client = MongoClient('localhost', 27017)
db = client['hh_db']
hh_db = db.vacancies

# %% [markdown]
# ## 3*)
# Написать функцию, которая будет добавлять в вашу базу данных только новые вакансии с сайта
#
# В данном случае буду сопоставлять по хэшу и искать таким образом полные повторы.
# Выше закоментировал фильтр с другой логикой. Там за одно считаются объявления, если совпадают организация и должность, даже если объявления были поданы в разное время, речь идет об одном предложении.

# %%
def make_hash(object):
    return zlib.adler32(bytes(repr(object), 'utf-8'))

# %%
def save_origin_vacancies_to_db(vacancies_list, return_dup_log = False):
    duplicate_log = []
    for vacancy in vacancies_list:
        vacancy_hash = make_hash(vacancy)
        vacancy["_id"] = vacancy_hash
        
        try:
            hh_db.insert_one(vacancy)
        except errors.DuplicateKeyError:
            duplicate_log.append(vacancy)
            
    if return_dup_log:
        return duplicate_log

# %% [markdown]
# ## 2)
# Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы
#
# Ограничен во времени сейчас. Так-то

# %%
def get_vacancies_with_salary_higher_than(salary):
    return_list = []
    for vacancy in hh_db.find({'salary_min': {'$gt': salary}} or {'salary_max': {'$gt': salary}}):
        return_list.append(vacancy)
    return return_list

# %%
save_origin_vacancies_to_db(data, return_dup_log=True)
# Out:
# [{'vacancy_name': 'Продавец-консультант мебели',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' ФАБРИКА МЕБЕЛИ 8 МАРТА',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': 150000,
#   'currency': 'руб.',
#   '_id': 2744614770},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Воронеж',
#   'salary_min': 26000,
#   'salary_max': 32500,
#   'currency': 'руб.',
#   '_id': 957511490},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Тольятти',
#   'salary_min': 27000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3076290746},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Качуева Нурия Рустямовна',
#   'city': 'Казань',
#   'salary_min': 50000,
#   'salary_max': 100000,
#   'currency': 'руб.',
#   '_id': 223838320},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' 585, Холдинг',
#   'city': 'Орехово-Зуево',
#   'salary_min': 40000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2359259469},
#  {'vacancy_name': 'Продавец-консультант в салон TELE-2',
#   'vacancy_add_time': '12 июня',
#   'company_name': 'ООО Дилер 24',
#   'city': 'Саяногорск',
#   'salary_min': 20000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3356522900},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' RECOSTBESHOES',
#   'city': 'Севастополь',
#   'salary_min': 30000,
#   'salary_max': 70000,
#   'currency': 'руб.',
#   '_id': 714958693},
#  {'vacancy_name': 'Продавец-консультант (ОбъГЭС)',
#   'vacancy_add_time': '12 июня',
#   'company_name': ' Красный Кролик',
#   'city': 'Новосибирск',
#   'salary_min': 25000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 2564784015},
#  {'vacancy_name': 'Продавец-консультант домашнего текстиля',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Иксанова Ильмира Ильдаровна',
#   'city': 'Оренбург',
#   'salary_min': 31000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 1338089493},
#  {'vacancy_name': 'Продавец-консультант в бутик женской одежды',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' PATRIZIA',
#   'city': 'Саратов',
#   'salary_min': 20000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 1414626423},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ТОО Восемь Озер, ТМ, Kazakhstan Motor City',
#   'city': 'Талгар',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 3044374644},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ИП Чупраков Александр Федорович',
#   'city': 'Липецк',
#   'salary_min': 20000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 677217679},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Малыш Валентина Павловна',
#   'city': 'Симферополь',
#   'salary_min': 30000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 649824056},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ИП Laguna Parfumes (ИП Обрегон Э)',
#   'city': 'Алматы',
#   'salary_min': 120000,
#   'salary_max': 300000,
#   'currency': 'KZT',
#   '_id': 2896261383},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Соколов В.Н.',
#   'city': 'Санкт-Петербург',
#   'salary_min': 30000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 978221131},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО ТД Комплект',
#   'city': 'Могилев',
#   'salary_min': 750,
#   'salary_max': 1500,
#   'currency': 'бел.руб.',
#   '_id': 3503453548},
#  {'vacancy_name': 'Продавец - консультант в магазин взрослых подарков',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть Магазинов Freeshop',
#   'city': 'Самара',
#   'salary_min': 15000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 4278687579},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО КАРИ',
#   'city': 'Балашов',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 1421370817},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Водяхин Олег Алексеевич',
#   'city': 'Владимир',
#   'salary_min': 18000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1596490173},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Озерск (Челябинская область)',
#   'salary_min': 23000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2705436264},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть комиссионных магазинов Restart',
#   'city': 'Усть-Илимск',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3202386654},
#  {'vacancy_name': 'Продавец-консультант магазин Секс Шоп',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Казаков Игорь Геннадьевич',
#   'city': 'Челябинск',
#   'salary_min': 20000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 4086340365},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ОДО Сэйсимед',
#   'city': 'Гомель',
#   'salary_min': 500,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 2590273820},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Maxi Dom (ИП Керемет)',
#   'city': 'Туркестан',
#   'salary_min': 80000,
#   'salary_max': 130000,
#   'currency': 'KZT',
#   '_id': 3516428358},
#  {'vacancy_name': 'Продавец-консультант ( ТЦ МЕГА Парнас)',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Компания «СПОРТМАСТЕР», Розничные продажи',
#   'city': 'Санкт-Петербург',
#   'salary_min': 36100,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1688449303},
#  {'vacancy_name': 'Продавец-консультант в магазин "Космо" в ТЦ "Дана Молл" (г. Минск, ул. П. Мстиславца,11)',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Космо-М',
#   'city': 'Минск',
#   'salary_min': 600,
#   'salary_max': 700,
#   'currency': 'бел.руб.',
#   '_id': 2717952715},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Федеральная сеть книжных магазинов «Читай-город»',
#   'city': 'Челябинск',
#   'salary_min': None,
#   'salary_max': 23400,
#   'currency': 'руб.',
#   '_id': 2850333024},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Гасанов Эхтирам Хосров Оглы',
#   'city': 'Санкт-Петербург',
#   'salary_min': 35000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 3204484563},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Дом обуви Тофа',
#   'city': 'Балашиха',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 233337184},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Rafam',
#   'city': 'Улан-Удэ',
#   'salary_min': 23000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 2418171849},
#  {'vacancy_name': 'Продавец-Консультант (г.Минск)',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ЗАО ЧИП и ДИП',
#   'city': 'Минск',
#   'salary_min': 335,
#   'salary_max': 635,
#   'currency': 'USD',
#   '_id': 1333816961},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Ливны',
#   'salary_min': 19600,
#   'salary_max': 24500,
#   'currency': 'руб.',
#   '_id': 3342824508},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' Сеть магазинов «ПОЛЕЗНЫЙ Рацион»',
#   'city': 'Иркутск',
#   'salary_min': 25000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 3307898860},
#  {'vacancy_name': 'Продавец-консультант (график 2/2)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Уровень',
#   'city': 'Липецк',
#   'salary_min': 24000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 2486071361},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '12 июня',
#   'company_name': 'ООО ПАРАЛИНЗ',
#   'city': 'Новокузнецк',
#   'salary_min': 15000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 4204164062},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Хабаровск',
#   'salary_min': 30000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 2111477620},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' SUNLIGHT',
#   'city': 'Томск',
#   'salary_min': 30000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2559663528},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Аксон',
#   'city': 'Смоленск',
#   'salary_min': 28000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3177539418},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО СЕВБЫТСЕРВИС',
#   'city': 'Архангельск',
#   'salary_min': 18000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 238057611},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Южно-Сахалинск',
#   'salary_min': 40000,
#   'salary_max': 100000,
#   'currency': 'руб.',
#   '_id': 544644552},
#  {'vacancy_name': 'Продавец-консультант направления PRO-аудио',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Drhead',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': 100000,
#   'currency': 'руб.',
#   '_id': 4157634538},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Компания Азимут',
#   'city': 'Витебск',
#   'salary_min': 440,
#   'salary_max': 980,
#   'currency': 'бел.руб.',
#   '_id': 1224702611},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Дом Камня',
#   'city': 'Кстово',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2685103356},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть магазинов нижнего белья Барышня',
#   'city': 'Канск',
#   'salary_min': 15000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 1502972524},
#  {'vacancy_name': 'Продавец-консультант в зоомагазин',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' EXOMENU',
#   'city': 'Москва',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 4083445776},
#  {'vacancy_name': 'Продавец-консультант (г. Краснотурьинск)',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Краснотурьинск',
#   'salary_min': 23500,
#   'salary_max': 70000,
#   'currency': 'руб.',
#   '_id': 2969613418},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ООО Цветомания',
#   'city': 'Санкт-Петербург',
#   'salary_min': 30000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 2969598651},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Дзержинский',
#   'salary_min': 48000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 3124395240},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' MARKA GROUP',
#   'city': 'Барнаул',
#   'salary_min': 20000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 4263338123},
#  {'vacancy_name': 'Продавец-консультант в магазин NAUMI в Аутлете Внуково',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Науми Стар 2',
#   'city': 'Москва',
#   'salary_min': 40000,
#   'salary_max': 90000,
#   'currency': 'руб.',
#   '_id': 2165608996},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО ПКФ Таврос',
#   'city': 'Белоусово',
#   'salary_min': 40000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 744780428},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Центр Ароматерапии Ирис (ИП Ирисова Светлана Владимировна)',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': 80000,
#   'currency': 'руб.',
#   '_id': 2181736006},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Крым Золото',
#   'city': 'Алушта',
#   'salary_min': 20000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3417730901},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО КАМИ-КИО',
#   'city': 'Петрозаводск',
#   'salary_min': 20000,
#   'salary_max': 40000,
#   'currency': 'руб.',
#   '_id': 133657360},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Курган',
#   'salary_min': 23000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2722468732},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' МаслоМаркет',
#   'city': 'Ростов-на-Дону',
#   'salary_min': 30000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 1411937582},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ООО Максимус-Ритейл',
#   'city': 'Москва',
#   'salary_min': 45000,
#   'salary_max': 70000,
#   'currency': 'руб.',
#   '_id': 3874452723},
#  {'vacancy_name': 'Продавец-консультант в ювелирный магазин "7 Карат"',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'УП Платина-груп, ЧУП',
#   'city': 'Минск',
#   'salary_min': 508,
#   'salary_max': 1023,
#   'currency': 'бел.руб.',
#   '_id': 3419707471},
#  {'vacancy_name': 'Продавец-консультант в adidas Performance',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' adidas, Фирменные магазины',
#   'city': 'Новороссийск',
#   'salary_min': None,
#   'salary_max': 23000,
#   'currency': 'руб.',
#   '_id': 3644295767},
#  {'vacancy_name': 'Продавец-консультант (ТРЦ Солнечный)',
#   'vacancy_add_time': '12 июня',
#   'company_name': ' KuchenLand',
#   'city': 'Новый Уренгой',
#   'salary_min': 33000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3904142362},
#  {'vacancy_name': 'Продавец-консультант отдела лечебной косметики',
#   'vacancy_add_time': '12 июня',
#   'company_name': 'ООО Трик-Фарма',
#   'city': 'Краснодар',
#   'salary_min': None,
#   'salary_max': 43000,
#   'currency': 'руб.',
#   '_id': 3287651695},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Голицыно',
#   'salary_min': 48000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 711882893},
#  {'vacancy_name': 'Продавец-консультант в магазин молодежной одежды Tally Weijl',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' TALLY WEIJL',
#   'city': 'Москва',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1378519368},
#  {'vacancy_name': 'Менеджер по продажам/продавец-консультант (ТЦ "Мега Белая дача")',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' НАВИКОМ, компания',
#   'city': 'Москва',
#   'salary_min': 40000,
#   'salary_max': 90000,
#   'currency': 'руб.',
#   '_id': 2079106350},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Норильск',
#   'salary_min': 36000,
#   'salary_max': 45000,
#   'currency': 'руб.',
#   '_id': 1542486122},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Евротюнинг (ООО Престиж)',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2674031174},
#  {'vacancy_name': 'Продавец-консультант (г. Лиски)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Разливной рай',
#   'city': 'Лиски',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 978024187},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Керама - Крым',
#   'city': 'Симферополь',
#   'salary_min': 30000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2296739679},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Москва',
#   'salary_min': 48000,
#   'salary_max': 80000,
#   'currency': 'руб.',
#   '_id': 4205802923},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Морозовск',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 2942335524},
#  {'vacancy_name': 'Продавец-консультант-кассир в магазин Веселая Затея',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Бондаренко Надежда Ивановна',
#   'city': 'Москва',
#   'salary_min': 30000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 2574035863},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Окна Юнион',
#   'city': 'Оренбург',
#   'salary_min': 24000,
#   'salary_max': 26000,
#   'currency': 'руб.',
#   '_id': 4092292264},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ООО Крым Золото',
#   'city': 'Судак',
#   'salary_min': 20000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2201251363},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Альметьевск',
#   'salary_min': 25110,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 4082866891},
#  {'vacancy_name': 'Продавец-консультант в adidas Performance',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' adidas, Фирменные магазины',
#   'city': 'Армавир',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 3341516903},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Горное Лоо\n                            Показать на карте\n                        ',
#   'salary_min': 28000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 1363122316},
#  {'vacancy_name': 'Продавец-консультант (в ТЦ Новая Рига Outlet Village)',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' KuchenLand',
#   'city': 'Истра\n                            Показать на карте\n                        ',
#   'salary_min': 40000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1163433232},
#  {'vacancy_name': 'Продавец-консультант (ТЦ "Седанка-Сити")',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Компания «СПОРТМАСТЕР», Начало карьеры',
#   'city': 'Владивосток',
#   'salary_min': 30000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 3737168366},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '3 июня',
#   'company_name': 'ОАО Чебоксары Лада',
#   'city': 'Новочебоксарск',
#   'salary_min': 40000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 887390123},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО ПАРК',
#   'city': 'Красногвардейское',
#   'salary_min': 20000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 955545319},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ООО Аккумуляторная компания Авто-Маркет',
#   'city': 'Воронеж',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 809210276},
#  {'vacancy_name': 'Продавец-консультант элитного алкоголя / Кавист',
#   'vacancy_add_time': None,
#   'company_name': ' Супермаркеты «Азбука Вкуса» ',
#   'city': 'Москва',
#   'salary_min': 45000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2531827068},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': None,
#   'company_name': ' Супермаркеты «Азбука Вкуса» ',
#   'city': 'Москва',
#   'salary_min': 40000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2443410460},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '12 июня',
#   'company_name': 'ООО Credit Asia',
#   'city': 'Ташкент',
#   'salary_min': 3000000,
#   'salary_max': 11000000,
#   'currency': 'сум',
#   '_id': 1415472798},
#  {'vacancy_name': 'Продавец-консультант ( ТЦ Афимолл)',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' Технопарк',
#   'city': 'Москва',
#   'salary_min': 60000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1855879165},
#  {'vacancy_name': 'Продавец-кассир/Продавец-консультант H&M (ТРЦ "Охта молл")',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' H&M',
#   'city': 'Санкт-Петербург',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 2129890569},
#  {'vacancy_name': 'Консультант продавец в бутик дорогой ткани',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Коллекция',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': 90000,
#   'currency': 'руб.',
#   '_id': 1135510706},
#  {'vacancy_name': 'Менеджер по продажам/ продавец-консультант ТЦ "Грин Сити"',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО ТД Аскона-Импорт',
#   'city': 'Минск',
#   'salary_min': 700,
#   'salary_max': 2500,
#   'currency': 'бел.руб.',
#   '_id': 3911819972},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Центр Электронных Технологий',
#   'city': 'Барановичи',
#   'salary_min': 800,
#   'salary_max': 1300,
#   'currency': 'бел.руб.',
#   '_id': 2730070303},
#  {'vacancy_name': 'Продавец-консультант одежды Befree',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО ПЛЭЙ МОДА',
#   'city': 'Минск',
#   'salary_min': 600,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 2607774449},
#  {'vacancy_name': 'Продавец-консультант/кассир',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Марк Формэль',
#   'city': 'Калининград',
#   'salary_min': 22000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 429883765},
#  {'vacancy_name': 'Продавец-консультант / менеджер по продажам',
#   'vacancy_add_time': '12 июня',
#   'company_name': ' М. Двери',
#   'city': 'Оренбург',
#   'salary_min': 25000,
#   'salary_max': 31000,
#   'currency': 'руб.',
#   '_id': 247169971},
#  {'vacancy_name': 'Продавец-консультант мебели',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' ФАБРИКА МЕБЕЛИ 8 МАРТА',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': 150000,
#   'currency': 'руб.',
#   '_id': 2744614770},
#  {'vacancy_name': 'Менеджер по продажам \\ Продавец-консультант (м. Аннино)',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО ВсеИнструменты.ру',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1833606993},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' МЕГАТОП',
#   'city': 'Минск',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 3450233483},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Белвингрупп',
#   'city': 'Борисов',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 769420176},
#  {'vacancy_name': 'Продавец-консультант в adidas Performance',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' adidas, Фирменные магазины',
#   'city': 'Геленджик',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 3692790813},
#  {'vacancy_name': 'Продавец-консультант товаров для дома (ТЦ "Оз Молл")',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Hoff',
#   'city': 'Краснодар',
#   'salary_min': 25000,
#   'salary_max': 28000,
#   'currency': 'руб.',
#   '_id': 892437500},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ТОО Компания СтройДекор, ТМ',
#   'city': 'Караганда',
#   'salary_min': None,
#   'salary_max': 300000,
#   'currency': 'KZT',
#   '_id': 2907078719},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Professional Beauty Guide',
#   'city': 'Нур-Султан',
#   'salary_min': 130000,
#   'salary_max': 180000,
#   'currency': 'KZT',
#   '_id': 114452924},
#  {'vacancy_name': 'Продавец-консультант (ТЦ "Замок")',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Respect',
#   'city': 'Минск',
#   'salary_min': 600,
#   'salary_max': 1000,
#   'currency': 'бел.руб.',
#   '_id': 2968087815},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Рекордсмен',
#   'city': 'Минск',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 3127994286},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Москва',
#   'salary_min': 48000,
#   'salary_max': 80000,
#   'currency': 'руб.',
#   '_id': 4205802923},
#  {'vacancy_name': 'Продавец - консультант по мебели и предметам интерьера',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ТОО Мир Паркета (BAU Group, ТОО)',
#   'city': 'Алматы',
#   'salary_min': 80000,
#   'salary_max': 500000,
#   'currency': 'KZT',
#   '_id': 1291951287},
#  {'vacancy_name': 'Продавец-консультант (ТЦ РИО)',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Коломна',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3724451141},
#  {'vacancy_name': 'Продавец-консультант в салон напольных покрытий',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ООО Ригонда-Коммерс Плюс',
#   'city': 'Минск',
#   'salary_min': 700,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 790733080},
#  {'vacancy_name': 'Администратор - консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ИП Иванова Виктория Ивановна',
#   'city': 'Волгоград',
#   'salary_min': 35000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 4164455715},
#  {'vacancy_name': 'Продавец-консультант (Гипермолл Горбушкин Двор)',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Сеть магазинов цифровой и бытовой техники DNS',
#   'city': 'Москва',
#   'salary_min': 41000,
#   'salary_max': 90000,
#   'currency': 'руб.',
#   '_id': 3055006745},
#  {'vacancy_name': 'Продавец-консультант по бренду JO MALONE (Кравт в ТЦ Дана Молл)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' КРАВТ',
#   'city': 'Минск',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 485721827},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ООО Огородик-центр',
#   'city': 'Минск',
#   'salary_min': 748,
#   'salary_max': 1379,
#   'currency': 'бел.руб.',
#   '_id': 3175839316},
#  {'vacancy_name': 'Продавец-консультант (ТЦ" Магнит")',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Торговая сеть «СПОРТМАСТЕР» (Беларусь)',
#   'city': 'Минск',
#   'salary_min': 900,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 180263933},
#  {'vacancy_name': 'Специалист по продажам/Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО ЛидерМатрасМаркет',
#   'city': 'Минск',
#   'salary_min': 700,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 1707383400},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Магадан',
#   'salary_min': 40000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 1092319048},
#  {'vacancy_name': 'Продавец-консультант услуги по химчистке',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Жабайканов',
#   'city': 'Алматы',
#   'salary_min': 100000,
#   'salary_max': 250000,
#   'currency': 'KZT',
#   '_id': 3798172669},
#  {'vacancy_name': 'Продавец-консультант (Родники)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Леруа Мерлен. Гипермаркеты',
#   'city': 'Новосибирск',
#   'salary_min': 27000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 403280021},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Евросеть, РБ',
#   'city': 'Брест',
#   'salary_min': 600,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 2075159922},
#  {'vacancy_name': 'Продавец-консультант (Кравт в ТЦ Арена Сити)',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' КРАВТ',
#   'city': 'Минск',
#   'salary_min': 500,
#   'salary_max': 700,
#   'currency': 'бел.руб.',
#   '_id': 964198212},
#  {'vacancy_name': 'Продавец-консультант салона связи',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Новомосковск (Тульская область)',
#   'salary_min': 22000,
#   'salary_max': 27500,
#   'currency': 'руб.',
#   '_id': 3696993642},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Связной, РБ',
#   'city': 'Гродно',
#   'salary_min': 600,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 4055920303},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Тольятти',
#   'salary_min': 20000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 1306818608},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Екатеринбург',
#   'salary_min': 30000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 1431928351},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '6 июня',
#   'company_name': ' 5LB',
#   'city': 'Москва',
#   'salary_min': 35000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 4286536925},
#  {'vacancy_name': 'Продавец-консультант (Боровая, 7а)',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ЗАО Пятый элемент, сеть магазинов',
#   'city': 'Минск',
#   'salary_min': 800,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 3403191742},
#  {'vacancy_name': 'Продавец-консультант (ТРЦ "Экспобел")',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Respect',
#   'city': 'Минск',
#   'salary_min': 500,
#   'salary_max': 1250,
#   'currency': 'бел.руб.',
#   '_id': 1293185780},
#  {'vacancy_name': 'Продавец-консультант техники (ст.м. "Каменная Горка")',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ЭЛЕКТРОСИЛА, сеть магазинов',
#   'city': 'Минск',
#   'salary_min': 800,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 2339874284},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Саранск',
#   'salary_min': 20000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 585791233},
#  {'vacancy_name': 'Продавец-консультант в магазин детской обуви Котофей в ТЦ МЕГА Теплый Стан',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Строчков С.Е.',
#   'city': 'Москва',
#   'salary_min': 40000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1431810187},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Respect',
#   'city': 'Минск',
#   'salary_min': 500,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 3375915616},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Чита',
#   'salary_min': 24000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 395604585},
#  {'vacancy_name': 'Продавец-консультант в отдел рыбы (м.Полежаевская )',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ВкусВилл',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': 55000,
#   'currency': 'руб.',
#   '_id': 1803324068},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Пенза',
#   'salary_min': 22000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 3506926672},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Евросеть, РБ',
#   'city': 'Гродно',
#   'salary_min': 600,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 3538448247},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Владивосток',
#   'salary_min': 39000,
#   'salary_max': 48000,
#   'currency': 'руб.',
#   '_id': 3169746162},
#  {'vacancy_name': 'Продавец-консультант (Кравт в ТЦ Корона Замок)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' КРАВТ',
#   'city': 'Минск',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 2239331432},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Ульяновск',
#   'salary_min': 25000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 2770500108},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Ульяновск',
#   'salary_min': 22000,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 2757065228},
#  {'vacancy_name': 'Продавец-консультант (м. Котельники)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Москва',
#   'salary_min': 48000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 2998830755},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Рязань',
#   'salary_min': 22000,
#   'salary_max': 40000,
#   'currency': 'руб.',
#   '_id': 4024595853},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Воронеж',
#   'salary_min': 30000,
#   'salary_max': 45000,
#   'currency': 'руб.',
#   '_id': 924743469},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Улан-Удэ',
#   'salary_min': 28500,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 2737600364},
#  {'vacancy_name': 'Продавец-консультант в г. Пинске',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' Удачник Сеть магазинов',
#   'city': 'Пинск',
#   'salary_min': 700,
#   'salary_max': 1500,
#   'currency': 'бел.руб.',
#   '_id': 3044247879},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Самара',
#   'salary_min': 22000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 4099503507},
#  {'vacancy_name': 'Дизайнер / Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ЗАО Вариа-Сервис',
#   'city': 'Воронеж',
#   'salary_min': 27000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 3888086597},
#  {'vacancy_name': 'Консультант элитного алкоголя/Кавист',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Супермаркеты «Азбука Вкуса» ',
#   'city': 'Москва',
#   'salary_min': 45000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2742916657},
#  {'vacancy_name': 'Продавец-консультант (Леруа Мерлен Одинцово)',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Леруа Мерлен. Гипермаркеты',
#   'city': 'Одинцово',
#   'salary_min': 37000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1147641443},
#  {'vacancy_name': 'Продавец-консультант/ Повар-обработчик рыбы',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ООО Джон Дори',
#   'city': 'Гомель',
#   'salary_min': 1100,
#   'salary_max': 1400,
#   'currency': 'бел.руб.',
#   '_id': 1234341059},
#  {'vacancy_name': 'Продавец-консультант (Кравт в ТЦ Экспобел)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' КРАВТ',
#   'city': 'Минск',
#   'salary_min': 500,
#   'salary_max': 700,
#   'currency': 'бел.руб.',
#   '_id': 1671986679},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Калининград',
#   'salary_min': 22000,
#   'salary_max': 27500,
#   'currency': 'руб.',
#   '_id': 1241349461},
#  {'vacancy_name': 'Продавец-консультант в отдел рыбы (Павшинская пойма)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ВкусВилл',
#   'city': 'Красногорск',
#   'salary_min': 50000,
#   'salary_max': 55000,
#   'currency': 'руб.',
#   '_id': 993301613},
#  {'vacancy_name': 'Продавец-консультант бытовой техники',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ЭЛЕКТРОСИЛА, сеть магазинов',
#   'city': 'Минск',
#   'salary_min': 800,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 3726743493},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Сызрань',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3412621180},
#  {'vacancy_name': 'Продавец-консультант в салон сотовой связи',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Калининград',
#   'salary_min': 22000,
#   'salary_max': 27500,
#   'currency': 'руб.',
#   '_id': 3660421175},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Воронеж',
#   'salary_min': 26000,
#   'salary_max': 32500,
#   'currency': 'руб.',
#   '_id': 957511490},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн',
#   'city': 'Елец',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 3291243058},
#  {'vacancy_name': 'Продавец-консультант бытовой техники (ТЦ "Экспобел")',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ЭЛЕКТРОСИЛА, сеть магазинов',
#   'city': 'Минск',
#   'salary_min': 900,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 2884020136},
#  {'vacancy_name': 'Продавец-консультант/ Повар-обработчик рыбы',
#   'vacancy_add_time': '8 июня',
#   'company_name': 'ООО Джон Дори',
#   'city': 'Могилев',
#   'salary_min': 1100,
#   'salary_max': 1400,
#   'currency': 'бел.руб.',
#   '_id': 3260845691},
#  {'vacancy_name': 'Продавец-консультант бытовой техники (ст.м."Могилёвская")',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ЭЛЕКТРОСИЛА, сеть магазинов',
#   'city': 'Минск',
#   'salary_min': 800,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 374582602},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Воронеж',
#   'salary_min': 26000,
#   'salary_max': 32500,
#   'currency': 'руб.',
#   '_id': 957511490},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Ярославль',
#   'salary_min': 24000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 1487239639},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' БелМодистка',
#   'city': 'Минск',
#   'salary_min': 1000,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 3657920467},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Кострома',
#   'salary_min': 22000,
#   'salary_max': 37000,
#   'currency': 'руб.',
#   '_id': 214988859},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Петрозаводск',
#   'salary_min': 22000,
#   'salary_max': 27500,
#   'currency': 'руб.',
#   '_id': 667516493},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Александров',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2548006275},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Кингисепп',
#   'salary_min': 25000,
#   'salary_max': 32000,
#   'currency': 'руб.',
#   '_id': 2032368165},
#  {'vacancy_name': 'Продавец-консультант в отдел строительных материалов (Северный м-н)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Леруа Мерлен. Гипермаркеты',
#   'city': 'Хабаровск',
#   'salary_min': 32000,
#   'salary_max': 32000,
#   'currency': 'руб.',
#   '_id': 745126634},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Новокузнецк',
#   'salary_min': 22000,
#   'salary_max': 40000,
#   'currency': 'руб.',
#   '_id': 4169825535},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Орск',
#   'salary_min': 20000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 799961668},
#  {'vacancy_name': 'Продавец-консультант в отдел Столярные изделия (Северный м-н)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Леруа Мерлен. Гипермаркеты',
#   'city': 'Хабаровск',
#   'salary_min': 32000,
#   'salary_max': 32000,
#   'currency': 'руб.',
#   '_id': 2536747720},
#  {'vacancy_name': 'Продавец-консультант в отдел Хранение (Северный м-н)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Леруа Мерлен. Гипермаркеты',
#   'city': 'Хабаровск',
#   'salary_min': 32000,
#   'salary_max': 32000,
#   'currency': 'руб.',
#   '_id': 1436657420},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '8 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Южно-Сахалинск',
#   'salary_min': 38000,
#   'salary_max': 47500,
#   'currency': 'руб.',
#   '_id': 4265902150},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Нахабино',
#   'salary_min': 48000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 758347912},
#  {'vacancy_name': 'Продавец-консультант салона связи',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Тула',
#   'salary_min': 26000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 4179198711},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Тольятти',
#   'salary_min': 27000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3076290746},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Серпухов',
#   'salary_min': 38000,
#   'salary_max': 47500,
#   'currency': 'руб.',
#   '_id': 277706821},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '5 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Брянск',
#   'salary_min': 22000,
#   'salary_max': 28000,
#   'currency': 'руб.',
#   '_id': 2380559649},
#  {'vacancy_name': 'Продавец-консультант в салон связи',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'УП ПроСеллер',
#   'city': 'Барановичи',
#   'salary_min': 700,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 3025700783},
#  {'vacancy_name': 'Продавец-консультант в салон связи "Билайн"',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Грозный',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 1631097111},
#  {'vacancy_name': 'Продавец-консультант (салон оптики)',
#   'vacancy_add_time': '12 июня',
#   'company_name': ' Точка Зрения, сеть салонов оптики',
#   'city': 'Санкт-Петербург',
#   'salary_min': 40000,
#   'salary_max': 65000,
#   'currency': 'руб.',
#   '_id': 1066640021},
#  {'vacancy_name': 'Продавец-консультант салона мебели (ТЦ "Мерей")',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ТОО ЕВРОМЕБЕЛЬ, ТМ (ТОО Торговая компания АЛА)',
#   'city': 'Алматы',
#   'salary_min': 150000,
#   'salary_max': 400000,
#   'currency': 'KZT',
#   '_id': 4031491394},
#  {'vacancy_name': 'Продавец-консультант в салоне нижнего белья',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ИП Темникова Наталья Анатольевна',
#   'city': 'Нижний Новгород',
#   'salary_min': 25000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 1608298617},
#  {'vacancy_name': 'Продавец-консультант (ТЦ "Dana Mall)',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Торговая сеть «СПОРТМАСТЕР» (Беларусь)',
#   'city': 'Минск',
#   'salary_min': 900,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 2226230806},
#  {'vacancy_name': 'Продавец-консультант в бутик',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' BORK',
#   'city': 'Москва',
#   'salary_min': 80000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2072209157},
#  {'vacancy_name': 'Продавец - консультант в салон',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Samsonite (ООО АУРА)',
#   'city': 'Новосибирск',
#   'salary_min': 30000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 1546287899},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Пилки',
#   'city': 'Киров (Кировская область)',
#   'salary_min': 20000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1115388554},
#  {'vacancy_name': 'Продавец-консультант в ювелирный салон',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Мастерские Владимира Михайлова',
#   'city': 'Москва',
#   'salary_min': 45000,
#   'salary_max': 70000,
#   'currency': 'руб.',
#   '_id': 2977209391},
#  {'vacancy_name': 'Продавец-консультант в салон Xiaomi',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО СДК Трейдинг',
#   'city': 'Серпухов',
#   'salary_min': 50000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3895558127},
#  {'vacancy_name': 'Продавец-консультант в ювелирный салон',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Дива, ювелирная сеть',
#   'city': 'Санкт-Петербург',
#   'salary_min': 30000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 1436456780},
#  {'vacancy_name': 'Продавец-консультант в ювелирный салон «Бриллиантовая Ручка»',
#   'vacancy_add_time': '12 июня',
#   'company_name': ' Сеть ювелирных салонов, Бриллиантовая ручка',
#   'city': 'Старый Оскол',
#   'salary_min': 23000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3099774982},
#  {'vacancy_name': 'Менеджер по продажам/ Продавец-консультант в салон Дверей',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' PROFIL DOORS (ООО ВФД-М)',
#   'city': 'Москва',
#   'salary_min': 70000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1488951466},
#  {'vacancy_name': 'Продавец-консультант профессиональной косметики для салонов красоты',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Mastershop',
#   'city': 'Батайск',
#   'salary_min': 12130,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 2389221414},
#  {'vacancy_name': 'Продавец-консультант в салон штор и солнцезащитных систем',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Карниз House',
#   'city': 'Невинномысск',
#   'salary_min': 20000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 984981032},
#  {'vacancy_name': 'Продавец-консультант косметики',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Профматрёшка - супермаркет профессиональной косметики',
#   'city': 'Балашиха',
#   'salary_min': 42000,
#   'salary_max': 85000,
#   'currency': 'руб.',
#   '_id': 1510126361},
#  {'vacancy_name': 'Продавец-консультант в зоомагазин',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Мурзик & Co',
#   'city': 'Пушкино (Московская область)',
#   'salary_min': 30000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3878064746},
#  {'vacancy_name': 'Продавец - Консультант в "Золотое Яблоко"',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Парфюмерный супермаркет Золотое Яблоко',
#   'city': 'Нижний Новгород',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 331396225},
#  {'vacancy_name': 'Продавец-консультант в бутик',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' BORK',
#   'city': 'Ростов-на-Дону',
#   'salary_min': 50000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3954995234},
#  {'vacancy_name': 'Продавец-консультант в магазин женской одежды',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Донец Юрий Васильевич',
#   'city': 'Электросталь',
#   'salary_min': 35000,
#   'salary_max': 45000,
#   'currency': 'руб.',
#   '_id': 2247205793},
#  {'vacancy_name': 'Продавец-консультант в салон мебели',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Лекс Торг',
#   'city': 'Гомель',
#   'salary_min': 800,
#   'salary_max': 1200,
#   'currency': 'бел.руб.',
#   '_id': 2039907065},
#  {'vacancy_name': 'Продавец-консультант органической косметики',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ИП Федорович Александра Андреевна',
#   'city': 'Новосибирск',
#   'salary_min': 24000,
#   'salary_max': 26000,
#   'currency': 'руб.',
#   '_id': 3158683487},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'УП Косметика Плюс',
#   'city': 'Солигорск',
#   'salary_min': 600,
# ...
#   'currency': 'руб.',
#   '_id': 3804855386},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Фермерские продукты',
#   'city': 'Екатеринбург',
#   'salary_min': 27000,
#   'salary_max': 32000,
#   'currency': 'руб.',
#   '_id': 3314974439},
#  {'vacancy_name': 'Продавец-консультант строительных материалов',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Люкстрой',
#   'city': 'Новосибирск',
#   'salary_min': None,
#   'salary_max': 40000,
#   'currency': 'руб.',
#   '_id': 3020985315},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Канск',
#   'salary_min': 30000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1937405122},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Сеть бутиков',
#   'city': 'Самара',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1194552498},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Глушково',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 1775532199},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Кизел',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 427586560},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Победа',
#   'city': 'Уфа',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3207488916},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Дверной Дизайн',
#   'city': 'Москва',
#   'salary_min': 30000,
#   'salary_max': 90000,
#   'currency': 'руб.',
#   '_id': 530543635},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Филиппов Никита Борисович',
#   'city': 'Арзамас',
#   'salary_min': 15000,
#   'salary_max': 18000,
#   'currency': 'руб.',
#   '_id': 747537031},
#  {'vacancy_name': 'Продавец-консультант (Царское золото)',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Залант',
#   'city': 'Гродно',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 1985772376},
#  {'vacancy_name': 'Продавец-консультант (мебельный салон)',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' ProDivani',
#   'city': 'Иркутск',
#   'salary_min': 20000,
#   'salary_max': 80000,
#   'currency': 'руб.',
#   '_id': 425424424},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '12 июня',
#   'company_name': 'ООО ТД СантехУрал',
#   'city': 'Челябинск',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3932911368},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' МагДвери',
#   'city': 'Северск (Томская область)',
#   'salary_min': 25000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 1928953397},
#  {'vacancy_name': 'Продавец-консультант в Максидом',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ВАЛВЕРДЕ',
#   'city': 'Санкт-Петербург',
#   'salary_min': 33000,
#   'salary_max': 38000,
#   'currency': 'руб.',
#   '_id': 3145826406},
#  {'vacancy_name': 'Продавец-консультант "Билайн"',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Дагомыс',
#   'salary_min': 28000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 4189159535},
#  {'vacancy_name': 'Продавец-консультант в телемагазин',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО ДомаТВ',
#   'city': 'Минск',
#   'salary_min': 1000,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 1966636882},
#  {'vacancy_name': 'Продавец-консультант в Знак, г.Барнаул',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' ВАЛВЕРДЕ',
#   'city': 'Барнаул',
#   'salary_min': 30000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 1954905215},
#  {'vacancy_name': 'Старший кассир/Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО ТД 1001 Платье',
#   'city': 'Москва',
#   'salary_min': 35000,
#   'salary_max': 45000,
#   'currency': 'руб.',
#   '_id': 1458274267},
#  {'vacancy_name': 'Продавец-консультант "Билайн"',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Усть-Донецкий',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 4266362846},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Выкса',
#   'salary_min': 20000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 920023997},
#  {'vacancy_name': 'Продавец-консультант в магазин сантехники',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ООО Аркона',
#   'city': 'Тольятти',
#   'salary_min': 20000,
#   'salary_max': 45000,
#   'currency': 'руб.',
#   '_id': 1117292300},
#  {'vacancy_name': 'Продавец-консультант в салон обуви "CALIPSO" в ТРЦ "КОЛЛАЖ" / ТЦ "ПАССАЖ"',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Чвырова Ираида Валентиновна',
#   'city': 'Пенза',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3643781577},
#  {'vacancy_name': 'Продавец-консультант в автомагазин',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Sezonkoles',
#   'city': 'Новосибирск',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 4007034576},
#  {'vacancy_name': 'Продавец-консультант (Мурманск Молл)',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Белвест',
#   'city': 'Мурманск',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2773121898},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Климов Геннадий',
#   'city': 'Краснодар',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 184776266},
#  {'vacancy_name': 'Продавец-консультант в магазин COLIN`S (ТЦ "Аутлето")',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'Иностр. п. ИООО БЭЛЕР РЕТАИЛЬ',
#   'city': 'Минск',
#   'salary_min': 280,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 2659818885},
#  {'vacancy_name': 'Продавец-консультант направления PRO-аудио',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Drhead',
#   'city': 'Москва',
#   'salary_min': 50000,
#   'salary_max': 100000,
#   'currency': 'руб.',
#   '_id': 4157634538},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' KuchenLand',
#   'city': 'Сургут',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3133431832},
#  {'vacancy_name': 'Продавец-консультант Центр Немецкой Моды Дюссельдорф. ТВЦ Каскад.',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' ТД Ниагара',
#   'city': 'Омск',
#   'salary_min': 17000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1605868994},
#  {'vacancy_name': 'Продавец-консультант автозапчастей для отечественных автомобилей',
#   'vacancy_add_time': '12 июня',
#   'company_name': 'ИП Шеенков С.Б',
#   'city': 'Нижний Новгород',
#   'salary_min': 27000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3112613132},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Группа компаний АртФолио',
#   'city': 'Новосибирск',
#   'salary_min': 30000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1250985197},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' ODEVAI',
#   'city': 'Москва',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3697827413},
#  {'vacancy_name': 'Продавец-консультант непродовольственных товаров',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Хозлавка',
#   'city': 'Екатеринбург',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 2718733693},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Леди Шарм, обособленное подразделение в г.Тюмень',
#   'city': 'Тюмень',
#   'salary_min': 20000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 378511036},
#  {'vacancy_name': 'Продавец-консультант (ул. Максима Горького)',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Женский Соблазн',
#   'city': 'Нижний Новгород',
#   'salary_min': None,
#   'salary_max': 29000,
#   'currency': 'руб.',
#   '_id': 2087295017},
#  {'vacancy_name': 'Продавец-консультант магазин Columbia в Хабаровске',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ИП Дунин Сергей Викторович',
#   'city': 'Хабаровск',
#   'salary_min': 30000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 667328918},
#  {'vacancy_name': 'Продавец-консультант автотоваров',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ИП Самохвалова Ксения Валерьевна',
#   'city': 'Челябинск',
#   'salary_min': None,
#   'salary_max': None,
#   'currency': None,
#   '_id': 1317640715},
#  {'vacancy_name': 'Продавец-консультант спецодежды,средств защиты',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' ТД Титан',
#   'city': 'Санкт-Петербург',
#   'salary_min': 25000,
#   'salary_max': 60000,
#   'currency': 'руб.',
#   '_id': 1217631110},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Сызрань',
#   'salary_min': 24000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3419764608},
#  {'vacancy_name': 'Продавец – консультант одежды немецких брендов',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' SV-Центр',
#   'city': 'Томск',
#   'salary_min': 25000,
#   'salary_max': 40000,
#   'currency': 'руб.',
#   '_id': 2493678719},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Бардаева Н.Н',
#   'city': 'Казань',
#   'salary_min': 40000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3790958187},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' KuchenLand',
#   'city': 'Москва',
#   'salary_min': 36100,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 4037107896},
#  {'vacancy_name': 'Продавец-консультант музыкального оборудования',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО ИНСТЭЛС',
#   'city': 'Москва',
#   'salary_min': 35000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 745901847},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Березовский (Кемеровская область)',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 2212009913},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Siberian Wellness',
#   'city': 'Нижний Новгород',
#   'salary_min': 22000,
#   'salary_max': 28000,
#   'currency': 'руб.',
#   '_id': 393375476},
#  {'vacancy_name': 'Продавец-консультант сотовой связи МегаФон',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ООО Казаков и К',
#   'city': 'Печора',
#   'salary_min': 15000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 2553580179},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' МагДвери',
#   'city': 'Томск',
#   'salary_min': 27000,
#   'salary_max': 45000,
#   'currency': 'руб.',
#   '_id': 2670356051},
#  {'vacancy_name': 'Продавец-консультант, INTIMISSIMI ТЦ "ГАГАРИНСКИЙ"',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ИП Турчина О. К.',
#   'city': 'Москва',
#   'salary_min': None,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 730694511},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Контактные центры',
#   'city': 'Новотроицк (Оренбургская область)',
#   'salary_min': 20000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 114597445},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Озеры',
#   'salary_min': 37000,
#   'salary_max': 47000,
#   'currency': 'руб.',
#   '_id': 1822585817},
#  {'vacancy_name': 'Продавец-консультант в шоурум тренажеров',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' СПОРТиЯ',
#   'city': 'Набережные Челны',
#   'salary_min': 25000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 3089534150},
#  {'vacancy_name': 'Продавец-консультант в салонах связи "Билайн"',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Контактные центры',
#   'city': 'Ставрополь',
#   'salary_min': 22400,
#   'salary_max': 30000,
#   'currency': 'руб.',
#   '_id': 1616224076},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Мулино',
#   'salary_min': 20000,
#   'salary_max': 25000,
#   'currency': 'руб.',
#   '_id': 4281365955},
#  {'vacancy_name': 'Продавец консультант в рыболовный магазин',
#   'vacancy_add_time': '12 июня',
#   'company_name': ' Рыболов',
#   'city': 'Оренбург',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 2711323947},
#  {'vacancy_name': 'Продавец-консультант строительных материалов',
#   'vacancy_add_time': '11 июня',
#   'company_name': 'ТОО Кундыз',
#   'city': 'Алматы',
#   'salary_min': 120000,
#   'salary_max': 150000,
#   'currency': 'KZT',
#   '_id': 3747579435},
#  {'vacancy_name': 'Менеджер по продажам мебели / Продавец консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': 'ИП Буробин Андрей Вячеславович',
#   'city': 'Москва',
#   'salary_min': 70000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 3066276122},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Наше Дело',
#   'city': 'Уфа',
#   'salary_min': 25000,
#   'salary_max': None,
#   'currency': 'руб.',
#   '_id': 1054304381},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Михнево (Московская область',
#   'salary_min': 38000,
#   'salary_max': 48000,
#   'currency': 'руб.',
#   '_id': 516395008},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Туймазы',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 712865544},
#  {'vacancy_name': 'Продавец-консультант в салон связи',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Березники',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 250710705},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ИП Бабкин Максим Александрович',
#   'city': 'Обнинск',
#   'salary_min': 21000,
#   'salary_max': 28000,
#   'currency': 'руб.',
#   '_id': 986416607},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Рошаль',
#   'salary_min': 28000,
#   'salary_max': 37000,
#   'currency': 'руб.',
#   '_id': 4057429406},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Данков',
#   'salary_min': 19000,
#   'salary_max': 24000,
#   'currency': 'руб.',
#   '_id': 197293527},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '9 июня',
#   'company_name': ' Столплит, Мебельная фабрика',
#   'city': 'Воронеж',
#   'salary_min': 25000,
#   'salary_max': 50000,
#   'currency': 'руб.',
#   '_id': 717848940},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Кумертау',
#   'salary_min': 20000,
#   'salary_max': 35000,
#   'currency': 'руб.',
#   '_id': 1014003751},
#  {'vacancy_name': 'Продавец-консультант в салон сотовой связи',
#   'vacancy_add_time': '11 июня',
#   'company_name': ' Билайн: Офисы продаж',
#   'city': 'Калининград',
#   'salary_min': 22000,
#   'salary_max': 27500,
#   'currency': 'руб.',
#   '_id': 1028102252},
#  {'vacancy_name': 'Продавец-консультант',
#   'vacancy_add_time': '10 июня',
#   'company_name': 'ООО Талифа Груп',
#   'city': 'Минск',
#   'salary_min': 700,
#   'salary_max': None,
#   'currency': 'бел.руб.',
#   '_id': 1395880583},
#  ...]

# %% [markdown]
# Вообще, было бы оптимально посчитать количество повторов объявлений за период времени. Например, одна контора за месяц разместила объявление 10 раз, а вторая - всего один. Это не значит, что первая - предоставит 10 вакансий, а вторая - одну. Но насколько кто заинтересован в поиске специалиста, да и многие другие неочевидные вещи можно выудить из такой информации.
#
# Но в данном случае мой парсер пробегает по сайту несколько раз, и вполне может многократно добавить одно и то же объявление. Довольно много придется переделать, чтобы различать, это полный дубль, или парсер собрал разные объявления о одном месте работы.
#
# Но еще более ценную информацию, пожалуй, будет нести дата удаления объявлений с маркетплейса. Если мы говорим про предложения вакансий, нашелся ли человек на другой день, или объявление обновлялось множество раз и висело месяц? Насколько люди готовы устраиваться на подобную работу за поставленную цену?
#
# 100000 зарплата для програмиста - это много?
#
# Если аналогичные объявления закрываются на второй - третий день - много.
#
# Если висят по месяцу и больше - мало, никто толковый не идет за эту сумму.
#
# Если поиск профессионала занимает 1-2 недели - оплата соответствует рыночной.
#
# Понятно, что напрямую это не спарсить. но если мониторинг идет в течение времени, например, парсим сайт раз-два в сутки, можно сопоставлять по хэшам. Если объявление есть в базе, но пропало с сайта (или висело больше месяца) - помечаем вакансию в базе закрытой, устанавливая текущую дату. Возможно, существуют какие-то более изящные решения. Но в целом очень бы хотелось отслеживать время жизни объявления, как меру ликвидности.

# %%
get_vacancies_with_salary_higher_than(100000)[0]
# Out:
# {'_id': 3748422264,
#  'vacancy_name': 'Продавец-консультант',
#  'vacancy_add_time': '12 июня',
#  'company_name': 'ООО Credit Asia',
#  'city': 'Ташкент',
#  'salary_min': 3000000,
#  'salary_max': 11000000,
#  'currency': 'сум'}
